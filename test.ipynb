# %%
import cegpy
from cegpy.trees.staged import StagedTree
from cegpy.trees.event import EventTree
import pandas as pd

# %% [markdown]
# Import medical dataset

# %%
df = pd.read_excel("medical_dm_modified.xlsx")

# %% [markdown]
# Create an event tree of the dataset

# %%
et = EventTree({'dataframe': df})
et.create_figure("et_fig_path")

# %% [markdown]
# created a staged tree of the dataset

# %%
st = StagedTree({'dataframe': df})
st.calculate_AHC_transitions()
st.create_figure("st_fig_path")
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/cegpy/trees/staged.py:244: RuntimeWarning: invalid value encountered in double_scalars
#   + self._calculate_sum_of_lg(prior2)
